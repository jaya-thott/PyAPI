# %% [markdown]
# <a href="https://colab.research.google.com/github/jaya-thott/PyAPI/blob/main/matlabplot_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([1, 8])
yp = np.array([4, 7])

plt.plot(xp, yp)
plt.show()
